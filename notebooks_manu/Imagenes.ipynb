# %%
import matplotlib.pyplot as plt
import numpy as np

afa = plt.imread("AFALogo.bmp").copy()
plt.gray()
plt.imshow(afa)

# %% [markdown]
# # Ejercicio 1 - AFA

# %%
plt.imshow(afa[80:160, 25:105])

# %% [markdown]
# # Ejercicio 2

# %%
estrellas = afa[0:35, 22:105]
estrellas = estrellas.T
plt.imshow(estrellas)

# %% [markdown]
# # Ejercicio 3

# %%
color_fondo = afa[0,0]
solo_fondo = afa.copy()
solo_fondo[afa != color_fondo] = 255
plt.imshow(solo_fondo)

# %% [markdown]
# # Ejercicio 4

# %%
color_fondo = afa[0,0]
fondo_blanco = afa.copy()
fondo_blanco[afa == color_fondo] = 255
plt.imshow(fondo_blanco)

# %% [markdown]
# # Ejercicio 5

# %%
plt.imshow(np.flip(afa, axis=-1))

# %% [markdown]
# # Ejercicio 6

# %%
grilla = fondo_blanco.copy()
grilla[::5,:] = 0
grilla[1::25,:] = 0
grilla[:,::5] = 0
grilla[:,1::25] = 0
plt.imshow(grilla)

# %% [markdown]
# # Seccion 2 - Pikachu y Charmander

# %%
imagen = plt.imread("pikachu_vs_charmander.jpeg")
plt.imshow(imagen)

# %%
imagen_metodo1 = (imagen.min(axis=2) + imagen.max(axis=2))/2
plt.imshow(imagen_metodo1)

# %%
imagen_metodo2 = imagen[:,:,0] + imagen[:,:,1] + imagen[:,:,2]
plt.imshow(imagen_metodo2)

# %%
imagen_metodo3 = 0.3*imagen[:,:,0] + 0.59*imagen[:,:,1] + 0.11*imagen[:,:,2]
plt.imshow(imagen_metodo3)
